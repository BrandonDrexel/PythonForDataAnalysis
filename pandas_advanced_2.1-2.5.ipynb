# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# Select and display the job_title and job_location columns for the first 5 rows of the DataFrame using the iloc method.

df.iloc[:5, [1, 2]]
# Out:
#                                            job_title  \
# 0  Senior Clinical Data Engineer / Principal Clin...
# 1                                       Data Analyst
# 2  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                             Data Engineer- Sr Jobs
#
#                    job_location
# 0                 Watertown, CT
# 1  Guadalajara, Jalisco, Mexico
# 2               Berlin, Germany
# 3               San Antonio, TX
# 4                Washington, DC

# %%
# Retrieve the columns starting with job_title all the way to job_posted_date for rows with an index of 5 to 9. Use the loc method.

df.loc[5:10, 'job_title':'job_posted_date']
# Out:
#                                    job_title         job_location  \
# 5                          GCP Data Engineer             Anywhere
# 6          Senior Data Engineer  - GCP Cloud         Dearborn, MI
# 7                              Data Engineer             Anywhere
# 8   Technology & Operations Business Analyst  Copenhagen, Denmark
# 9                          Data Scientist II             Anywhere
# 10      Erfahrene*r Data Engineer*in (m/w/d)   Basel, Switzerland
#
#              job_via         job_schedule_type  job_work_from_home  \
# 5   via ZipRecruiter  Contractor and Temp work                True
# 6       via LinkedIn                 Full-time               False
# 7       via LinkedIn                 Full-time                True
# 8    via Trabajo.org                 Full-time               False
# 9   via ZipRecruiter                 Full-time                True
# 10      via LinkedIn                 Full-time               False
#
#             search_location     job_posted_date
# 5                   Georgia 2023-11-07 14:01:59
# 6    Florida, United States 2023-03-27 13:18:18
# 7                   Romania 2023-12-07 13:40:49
# 8                   Denmark 2023-06-05 13:44:34
# 9   New York, United States 2023-04-23 13:02:57
# 10              Switzerland 2023-04-17 13:27:32

# %%
# Retrieve the job_title and salary_year_avg for the first 15 rows where the job_country is 'United States'. Use the iloc method.

df_us = df[df['job_country'] == 'United States']
df_us.iloc[:15][['job_title', 'salary_year_avg']]
# Out:
#                                             job_title  salary_year_avg
# 0   Senior Clinical Data Engineer / Principal Clin...              NaN
# 3   LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...              NaN
# 5                                   GCP Data Engineer              NaN
# 6                   Senior Data Engineer  - GCP Cloud              NaN
# 9                                   Data Scientist II              NaN
# 11                                      Data Engineer              NaN
# 13                               Senior Data Engineer              NaN
# 17                             Data Science Team Lead              NaN
# 26                                      Data Engineer              NaN
# 27  Principal Data Engineer (Lead), Knowledge Grap...              NaN
# 30     Senior Data Engineer (Work from home Eligible)              NaN
# 32   Sr. Data Scientist (NLP) - Full-time / Part-time              NaN
# 35                        Data Engineer - Royal Canin              NaN
# 36                                       Data Analyst              NaN
# 37                     Data Engineer III - Now Hiring              NaN

# %%
# Select and display the job_title, job_location, and job_posted_date columns for rows where the job_posted_date is after '2023-05-01' using the loc method.

#df_late = df[df['job_posted_date'] > '2023-05-01']
#loc['job_posted_date' > '2023-05-01']
df.loc[df['job_posted_date'] > '2023-05-01', ['job_title', 'job_location', 'job_posted_date']]
# Out:
#                                                 job_title  \
# 0       Senior Clinical Data Engineer / Principal Clin...
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4                                  Data Engineer- Sr Jobs
# 5                                       GCP Data Engineer
# ...                                                   ...
# 785694                                      Data Engineer
# 785696                          Senior Analytics Engineer
# 785698      Data Engineer, Gerencia Business Intelligence
# 785701      Data Engineer, Gerencia Business Intelligence
# 785706                               Junior Data Engineer
#
#                      job_location     job_posted_date
# 0                   Watertown, CT 2023-06-16 13:44:15
# 2                 Berlin, Germany 2023-10-10 13:14:55
# 3                 San Antonio, TX 2023-07-04 13:01:41
# 4                  Washington, DC 2023-08-07 14:29:36
# 5                        Anywhere 2023-11-07 14:01:59
# ...                           ...                 ...
# 785694              Graz, Austria 2023-05-07 07:07:37
# 785696  Colombia, Huila, Colombia 2023-10-23 06:31:25
# 785698          Las Condes, Chile 2023-08-09 06:32:00
# 785701            Santiago, Chile 2023-08-09 06:31:57
# 785706                 Lima, Peru 2023-11-08 06:34:48
#
# [502338 rows x 3 columns]

# %%
#Remove rows where the salary_year_avg column has missing values. Display the number of rows before and after removing.

droppies = df.dropna(subset='salary_year_avg')
len(droppies), len(df)
# Out:
# (22003, 785741)

# %%
# Remove duplicate rows from the DataFrame based on the job_location column. Display the number of rows before and after removing duplicates.
dropped_dupies = df.drop_duplicates(subset='job_location')
len(dropped_dupies), len(df)
# Out:
# (17218, 785741)

# %%
# Fill missing values in the salary_rate column with the string 'Unknown'. Display the first 10 rows of the salary_rate column before and after filling.

fillies = df.fillna({'salary_rate':'Unknown'})
df['salary_rate'].head(10), fillies['salary_rate'].head(10)
# Out:
# (0    None
#  1    None
#  2    None
#  3    None
#  4    None
#  5    None
#  6    None
#  7    None
#  8    None
#  9    None
#  Name: salary_rate, dtype: object,
#  0    Unknown
#  1    Unknown
#  2    Unknown
#  3    Unknown
#  4    Unknown
#  5    Unknown
#  6    Unknown
#  7    Unknown
#  8    Unknown
#  9    Unknown
#  Name: salary_rate, dtype: object)

# %%
# Create a copy of the DataFrame and drop rows where the salary_year_avg column has missing values. Display the first 5 rows of the cleaned DataFrame.

df_copy = df.copy()
df_copy.dropna(subset='salary_year_avg').head()
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# 92          Full-time                True    Illinois, United States
# 100         Full-time               False  California, United States
# 109         Full-time                True    Illinois, United States
#
#         job_posted_date  job_no_degree_mention  job_health_insurance  \
# 28  2023-08-01 13:37:57                  False                 False
# 77  2023-06-26 14:22:54                  False                 False
# 92  2023-02-21 13:29:59                  False                  True
# 100 2023-07-31 13:01:18                  False                  True
# 109 2023-10-12 13:02:19                  False                  True
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 28      Costa Rica        year         109500.0              NaN
# 77           Sudan        year         140000.0              NaN
# 92   United States        year         120000.0              NaN
# 100  United States        year         228222.0              NaN
# 109  United States        year          89000.0              NaN
#
#                         company_name  \
# 28                          Netskope
# 77                        Intelletec
# 92                      Apex Systems
# 100                           TikTok
# 109  Get It Recruit - Transportation
#
#                                             job_skills  \
# 28                                   ['gdpr', 'excel']
# 77   ['mongodb', 'mongodb', 'python', 'r', 'sql', '...
# 92                                   ['sql', 'python']
# 100                  ['sql', 'r', 'python', 'express']
# 109              ['python', 'r', 'alteryx', 'tableau']
#
#                                        job_type_skills
# 28   {'analyst_tools': ['excel'], 'libraries': ['gd...
# 77   {'analyst_tools': ['tableau'], 'cloud': ['orac...
# 92                  {'programming': ['sql', 'python']}
# 100  {'programming': ['sql', 'r', 'python'], 'webfr...
# 109  {'analyst_tools': ['alteryx', 'tableau'], 'pro...

# %%
# Create a new DataFrame that is a random sample of 10% of the original DataFrame. Display the first 5 rows of the sampled DataFrame.
df_copy = df.copy()
df_copy.sample(frac=0.1).head()
# Out:
#           job_title_short                                 job_title  \
# 447989       Data Analyst                              Data Analyst
# 279704       Data Analyst  Clinical Data Analyst-Special Population
# 693378  Software Engineer                        Graduate Developer
# 636154     Data Scientist               EMEA Pricing Data Scientist
# 45621      Data Scientist                        Jr. Data Scientist
#
#                      job_location           job_via job_schedule_type  \
# 447989               Santa Fe, NM      via LinkedIn         Full-time
# 279704              Bradenton, FL  via ZipRecruiter         Full-time
# 693378             United Kingdom         via BeBee         Full-time
# 636154                     France         via BeBee         Full-time
# 45621   Faridabad, Haryana, India   via SimplyHired         Full-time
#
#         job_work_from_home         search_location     job_posted_date  \
# 447989               False                   Sudan 2023-08-17 14:38:52
# 279704               False  Florida, United States 2023-03-02 07:03:40
# 693378               False          United Kingdom 2023-11-12 10:30:37
# 636154               False                  France 2023-06-20 12:25:24
# 45621                False                   India 2023-10-30 06:09:13
#
#         job_no_degree_mention  job_health_insurance     job_country  \
# 447989                   True                  True           Sudan
# 279704                  False                 False   United States
# 693378                  False                 False  United Kingdom
# 636154                  False                 False          France
# 45621                   False                 False           India
#
#        salary_rate  salary_year_avg  salary_hour_avg  \
# 447989        None              NaN              NaN
# 279704        None              NaN              NaN
# 693378        None              NaN              NaN
# 636154        None              NaN              NaN
# 45621         None              NaN              NaN
#
#                        company_name             job_skills  \
# 447989     Santa Fe Recovery Center                   None
# 279704                   MCR Health                   None
# 693378                     FLTalent  ['javascript', 'sql']
# 636154            Otis Elevator Co.                 ['go']
# 45621   Utopiic Innovations Pvt Ltd        ['python', 'r']
#
#                                job_type_skills
# 447989                                    None
# 279704                                    None
# 693378  {'programming': ['javascript', 'sql']}
# 636154                 {'programming': ['go']}
# 45621         {'programming': ['python', 'r']}

# %%
# Create a copy of the original DataFrame and fill in missing values in the salary_year_avg column with the median salary. Display the first 5 rows of the altered DataFrame.

df_copy = df.copy()
median_salary = df['salary_year_avg'].median()
df_copy.fillna({'salary_year_avg':median_salary}, inplace=True)
df_copy.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0         115000.0              NaN          Boehringer Ingelheim
# 1         115000.0              NaN    Hewlett Packard Enterprise
# 2         115000.0              NaN      ALPHA Augmented Services
# 3         115000.0              NaN  Southwest Research Institute
# 4         115000.0              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
# Create a pivot table to count the number of job postings for each job_title_short and job_country. Display the first 10 rows of the resulting pivot table.

pivot = df.pivot_table(index=['job_title_short','job_country'], aggfunc='size')
pivot.head(10)
# Out:
# job_title_short   job_country
# Business Analyst  Afghanistan      4
#                   Albania         11
#                   Algeria         21
#                   Angola           1
#                   Argentina      453
#                   Armenia         29
#                   Australia      928
#                   Austria        738
#                   Azerbaijan      16
#                   Bahamas          5
# dtype: int64

# %%
# Create a pivot table to find the maximum, minimum, and average salary_year_avg for each company_name. Display the first 5 rows of the resulting pivot table.
pivot2 = df.pivot_table(index='company_name', values='salary_year_avg', aggfunc=['max', 'min', 'mean'])
pivot2.head()
# Out:
#                                     max             min            mean
#                         salary_year_avg salary_year_avg salary_year_avg
# company_name
# #twiceasnice Recruiting   120000.000000    61000.000000    77750.000000
# /dev/color                125000.000000   125000.000000   125000.000000
# 0nward Select              92500.000000    92500.000000    92500.000000
# 1 Point System            137290.484375   137290.484375   137290.484375
# 1 Point System LLC.       170000.000000   170000.000000   170000.000000

# %%
# Create a pivot table to calculate the median of salary_year_avg for each company_name and job_country:
# Filter the pivot table to only include 'Data Scientist' roles.
# Then filter the pivot table to only include company_name with a median salary_year_avg greater than 200,000.
# Display the first 10 rows of the resulting pivot table.

ds_only = df[df['job_title_short'] == 'Data Scientist']
pivot3 = ds_only.pivot_table(index=['company_name', 'job_country'], values='salary_year_avg', aggfunc='median')
over2k = pivot3[pivot3['salary_year_avg'] > 200000]

over2k.head(10)
# Out:
#                                    salary_year_avg
# company_name        job_country
# ACT                 Sudan                 225000.0
#                     United States         225000.0
# Abbott              United States         204000.0
# Airbnb              United States         212500.0
# Airtable            Sudan                 215500.0
#                     United States         233500.0
# Algo Capital Group  Sudan                 325000.0
#                     United States         350000.0
# Amadeus Search      United States         232500.0
# Analog Devices, Inc United States         375000.0

# %%
# Set the job_posted_date column as the index of the DataFrame and display the first 5 rows.

new_index = df.copy()
new_index.set_index('job_posted_date', inplace=True)
new_index.head()
# Out:
#                           job_title_short  \
# job_posted_date
# 2023-06-16 13:44:15  Senior Data Engineer
# 2023-01-14 13:18:07          Data Analyst
# 2023-10-10 13:14:55         Data Engineer
# 2023-07-04 13:01:41         Data Engineer
# 2023-08-07 14:29:36         Data Engineer
#
#                                                              job_title  \
# job_posted_date
# 2023-06-16 13:44:15  Senior Clinical Data Engineer / Principal Clin...
# 2023-01-14 13:18:07                                       Data Analyst
# 2023-10-10 13:14:55  Data Engineer/Scientist/Analyst, Mid or Senior...
# 2023-07-04 13:01:41  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 2023-08-07 14:29:36                             Data Engineer- Sr Jobs
#
#                                      job_location             job_via  \
# job_posted_date
# 2023-06-16 13:44:15                 Watertown, CT     via Work Nearby
# 2023-01-14 13:18:07  Guadalajara, Jalisco, Mexico    via BeBee México
# 2023-10-10 13:14:55               Berlin, Germany        via LinkedIn
# 2023-07-04 13:01:41               San Antonio, TX   via Diversity.com
# 2023-08-07 14:29:36                Washington, DC  via Clearance Jobs
#
#                     job_schedule_type  job_work_from_home  \
# job_posted_date
# 2023-06-16 13:44:15         Full-time               False
# 2023-01-14 13:18:07         Full-time               False
# 2023-10-10 13:14:55         Full-time               False
# 2023-07-04 13:01:41         Full-time               False
# 2023-08-07 14:29:36         Full-time               False
#
#                           search_location  job_no_degree_mention  \
# job_posted_date
# 2023-06-16 13:44:15  Texas, United States                  False
# 2023-01-14 13:18:07                Mexico                  False
# 2023-10-10 13:14:55               Germany                  False
# 2023-07-04 13:01:41  Texas, United States                   True
# 2023-08-07 14:29:36                 Sudan                  False
#
#                      job_health_insurance    job_country salary_rate  \
# job_posted_date
# 2023-06-16 13:44:15                 False  United States        None
# 2023-01-14 13:18:07                 False         Mexico        None
# 2023-10-10 13:14:55                 False        Germany        None
# 2023-07-04 13:01:41                 False  United States        None
# 2023-08-07 14:29:36                 False          Sudan        None
#
#                      salary_year_avg  salary_hour_avg  \
# job_posted_date
# 2023-06-16 13:44:15              NaN              NaN
# 2023-01-14 13:18:07              NaN              NaN
# 2023-10-10 13:14:55              NaN              NaN
# 2023-07-04 13:01:41              NaN              NaN
# 2023-08-07 14:29:36              NaN              NaN
#
#                                      company_name  \
# job_posted_date
# 2023-06-16 13:44:15          Boehringer Ingelheim
# 2023-01-14 13:18:07    Hewlett Packard Enterprise
# 2023-10-10 13:14:55      ALPHA Augmented Services
# 2023-07-04 13:01:41  Southwest Research Institute
# 2023-08-07 14:29:36               Kristina Daniel
#
#                                                             job_skills  \
# job_posted_date
# 2023-06-16 13:44:15                                               None
# 2023-01-14 13:18:07  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2023-10-10 13:14:55  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 2023-07-04 13:01:41  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 2023-08-07 14:29:36  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                                        job_type_skills
# job_posted_date
# 2023-06-16 13:44:15                                               None
# 2023-01-14 13:18:07  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2023-10-10 13:14:55  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 2023-07-04 13:01:41  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 2023-08-07 14:29:36  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
# Reset the index of the DataFrame from the last problem (where job_posted_date column is the index) to the default integer index and drop the existing index. Display the first 5 rows.

new_index.reset_index(drop=True, inplace=True)
new_index.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location  job_no_degree_mention  \
# 0               False  Texas, United States                  False
# 1               False                Mexico                  False
# 2               False               Germany                  False
# 3               False  Texas, United States                   True
# 4               False                 Sudan                  False
#
#    job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                 False  United States        None              NaN
# 1                 False         Mexico        None              NaN
# 2                 False        Germany        None              NaN
# 3                 False  United States        None              NaN
# 4                 False          Sudan        None              NaN
#
#    salary_hour_avg                  company_name  \
# 0              NaN          Boehringer Ingelheim
# 1              NaN    Hewlett Packard Enterprise
# 2              NaN      ALPHA Augmented Services
# 3              NaN  Southwest Research Institute
# 4              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
# Create a pivot table to calculate the median salary_year_avg for each company_name and sort the index in descending order. Display the first 5 rows.

pivot4 = df.pivot_table(index='company_name', values='salary_year_avg', aggfunc='median')
pivot4.sort_index(ascending=False, inplace=True)
pivot4.head()
# Out:
#                                     salary_year_avg
# company_name
# ​Illinois State Board of Education          62536.0
# Технологическая компания                   280000.0
# ЛАНИТ                                      400000.0
# ztp                                         95000.0
# zooplus SE                                 161750.0

# %%
# Create a pivot table to calculate the median salary_year_avg
# for each job_title_short, reset the index of the resulting pivot table,
# then set the index to salary_year_avg.
# Display the first 5 rows.

pivot5 = df.pivot_table(index='job_title_short', values='salary_year_avg', aggfunc='median')
pivot5.reset_index(inplace=True)
pivot5.set_index('salary_year_avg', inplace=True)
pivot5.head()
# Out:
#                   job_title_short
# salary_year_avg
# 85000.0          Business Analyst
# 90000.0            Cloud Engineer
# 90000.0              Data Analyst
# 125000.0            Data Engineer
# 127500.0           Data Scientist
