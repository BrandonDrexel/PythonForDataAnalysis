# %%
import pandas as pd
import matplotlib.pyplot as plt
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# Export the DataFrame to a CSV file named data_jobs_export.csv without including the index. Inspect the contents of the CSV exported.

df.to_csv('data_jobs_export.csv', index=False)
job_data = pd.read_csv('data_jobs_export.csv')
job_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 785741 entries, 0 to 785740
# Data columns (total 17 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   job_title_short        785741 non-null  object
#  1   job_title              785740 non-null  object
#  2   job_location           784696 non-null  object
#  3   job_via                785733 non-null  object
#  4   job_schedule_type      773074 non-null  object
#  5   job_work_from_home     785741 non-null  bool
#  6   search_location        785741 non-null  object
#  7   job_posted_date        785741 non-null  object
#  8   job_no_degree_mention  785741 non-null  bool
#  9   job_health_insurance   785741 non-null  bool
#  10  job_country            785692 non-null  object
#  11  salary_rate            33067 non-null   object
#  12  salary_year_avg        22003 non-null   float64
#  13  salary_hour_avg        10662 non-null   float64
#  14  company_name           785723 non-null  object
#  15  job_skills             668704 non-null  object
#  16  job_type_skills        668704 non-null  object
# dtypes: bool(3), float64(2), object(12)
# memory usage: 86.2+ MB

# %%
# Filter the DataFrame to include only job postings with 'Data Scientist' in the job_title_short column.
# Export the filtered DataFrame to a CSV file named data_scientist_jobs.csv without including the index.
# Inspect that the CSV has been exported with the correct filtered data.

df_ds = df[df['job_title_short'] ==  'Data Scientist']
df_ds.to_csv('data_scientist_jobs.csv', index=False)
ds_jobs = pd.read_csv('data_scientist_jobs.csv')
ds_jobs.head(15)
# Out:
#    job_title_short                                          job_title  \
# 0   Data Scientist                                  Data Scientist II
# 1   Data Scientist                             Data Science Team Lead
# 2   Data Scientist                                     Data Scientist
# 3   Data Scientist                                     Data Scientist
# 4   Data Scientist  Stage - data scientist – génération ia de donn...
# 5   Data Scientist                      Data Scientist (DataLab Team)
# 6   Data Scientist                                CRM Data Specialist
# 7   Data Scientist                                     Data Scientist
# 8   Data Scientist   Sr. Data Scientist (NLP) - Full-time / Part-time
# 9   Data Scientist        Data Scientist, Data Strategy and Analytics
# 10  Data Scientist                                   Data Scientist I
# 11  Data Scientist  Binance Accelerator Program - Data Scientist (...
# 12  Data Scientist              Data Scientist SME or Program Manager
# 13  Data Scientist                                     Data Scientist
# 14  Data Scientist                                     Data Scientist
#
#                                job_location  \
# 0                                  Anywhere
# 1                                Laurel, MD
# 2                  Pune, Maharashtra, India
# 3                         Zaventem, Belgium
# 4                Asnières-sur-Seine, France
# 5                                  Anywhere
# 6   San José Province, San José, Costa Rica
# 7                  Pune, Maharashtra, India
# 8                                Dallas, TX
# 9                               Alameda, CA
# 10                                Paris, KY
# 11                                Singapore
# 12                               Austin, TX
# 13    São Paulo, State of São Paulo, Brazil
# 14                               Austin, TX
#
#                                               job_via job_schedule_type  \
# 0                                    via ZipRecruiter         Full-time
# 1   via APL Careers - Johns Hopkins University App...         Full-time
# 2                                          via Indeed         Full-time
# 3                                  via BeBee Belgique         Full-time
# 4                                        via Jobijoba         Full-time
# 5                                        via LinkedIn         Full-time
# 6                                     via Ai-Jobs.net         Full-time
# 7                                          via Exusia         Full-time
# 8                                        via Snagajob         Full-time
# 9                                     via Trabajo.org         Full-time
# 10                                   via Jobs By Care         Full-time
# 11                                       via LinkedIn        Contractor
# 12                                       via LinkedIn        Contractor
# 13                                          via BeBee         Full-time
# 14                                          via BeBee         Full-time
#
#     job_work_from_home            search_location      job_posted_date  \
# 0                 True    New York, United States  2023-04-23 13:02:57
# 1                False                    Georgia  2023-06-13 13:25:17
# 2                False                      India  2023-04-26 13:20:12
# 3                False                    Belgium  2023-01-31 13:53:38
# 4                False                     France  2023-02-23 13:41:21
# 5                 True                     Serbia  2023-06-27 13:46:46
# 6                False                 Costa Rica  2023-08-01 13:37:57
# 7                False                      India  2023-03-26 13:16:20
# 8                False       Texas, United States  2023-03-13 13:07:03
# 9                False  California, United States  2023-04-26 13:05:10
# 10               False                    Georgia  2023-11-13 14:59:39
# 11               False                  Singapore  2023-04-12 13:53:26
# 12               False       Texas, United States  2023-11-16 13:03:10
# 13               False                     Brazil  2023-01-03 23:02:27
# 14               False                      Sudan  2023-02-17 14:01:39
#
#     job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                   False                 False  United States         NaN
# 1                   False                  True  United States         NaN
# 2                   False                 False          India         NaN
# 3                   False                 False        Belgium         NaN
# 4                   False                 False         France         NaN
# 5                   False                 False         Serbia         NaN
# 6                   False                 False     Costa Rica        year
# 7                   False                 False          India         NaN
# 8                   False                  True  United States         NaN
# 9                   False                 False  United States         NaN
# 10                  False                 False  United States         NaN
# 11                  False                 False      Singapore         NaN
# 12                  False                 False  United States         NaN
# 13                  False                 False         Brazil         NaN
# 14                  False                  True          Sudan         NaN
#
#     salary_year_avg  salary_hour_avg  \
# 0               NaN              NaN
# 1               NaN              NaN
# 2               NaN              NaN
# 3               NaN              NaN
# 4               NaN              NaN
# 5               NaN              NaN
# 6          109500.0              NaN
# 7               NaN              NaN
# 8               NaN              NaN
# 9               NaN              NaN
# 10              NaN              NaN
# 11              NaN              NaN
# 12              NaN              NaN
# 13              NaN              NaN
# 14              NaN              NaN
#
#                                 company_name  \
# 0                 Radwell International, LLC
# 1   Johns Hopkins Applied Physics Laboratory
# 2                          Bitwise Solutions
# 3                                   Devoteam
# 4                            Credit Agricole
# 5                                    Semrush
# 6                                   Netskope
# 7                                     Exusia
# 8                                   MCKESSON
# 9                                     Abbott
# 10           Appalachian Regional Healthcare
# 11                                   Binance
# 12                                  Mavinsys
# 13                                      Mars
# 14                                ClosedLoop
#
#                                            job_skills  \
# 0   ['sql', 'python', 'r', 'mongodb', 'mongodb', '...
# 1                              ['go', 'apl', 'excel']
# 2   ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 3   ['r', 'python', 'sql', 'pandas', 'numpy', 'sci...
# 4                                                 NaN
# 5                                          ['python']
# 6                                   ['gdpr', 'excel']
# 7                                                 NaN
# 8   ['python', 'azure', 'databricks', 'pyspark', '...
# 9                                                 NaN
# 10  ['r', 'sql', 'python', 'scala', 'java', 'c++',...
# 11                        ['python', 'java', 'scala']
# 12  ['sql', 'html', 'css', 'javascript', 'lua', 'r...
# 13                         ['python', 'sql', 'azure']
# 14                                   ['python', 'go']
#
#                                       job_type_skills
# 0   {'analyst_tools': ['excel'], 'cloud': ['azure'...
# 1   {'analyst_tools': ['excel'], 'programming': ['...
# 2   {'analyst_tools': ['tableau'], 'libraries': ['...
# 3   {'libraries': ['pandas', 'numpy', 'scikit-lear...
# 4                                                 NaN
# 5                         {'programming': ['python']}
# 6   {'analyst_tools': ['excel'], 'libraries': ['gd...
# 7                                                 NaN
# 8   {'cloud': ['azure', 'databricks'], 'libraries'...
# 9                                                 NaN
# 10  {'analyst_tools': ['tableau'], 'libraries': ['...
# 11       {'programming': ['python', 'java', 'scala']}
# 12  {'analyst_tools': ['tableau'], 'cloud': ['reds...
# 13  {'cloud': ['azure'], 'programming': ['python',...
# 14                  {'programming': ['python', 'go']}

# %%
# Filter the DataFrame to include only job postings with 'New York, NY' in the job_location column.
# Export the filtered DataFrame to an Excel file named new_york_jobs.xlsx without including the index.
# Display the first 5 rows of the filtered DataFrame to confirm the export.

df_ny = df[df['job_location'] == 'New York, NY']
df_ny.to_excel('new_york_jobs.xlsx', index=False)
pd.read_excel('new_york_jobs.xlsx').head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer                               Senior Data Engineer
# 1         Data Engineer                                      Data Engineer
# 2  Senior Data Engineer                         Cyber Senior Data Engineer
# 3          Data Analyst  Financial Systems – Business Analyst/ Data Ana...
# 4          Data Analyst                             Reporting Data Analyst
#
#    job_location                   job_via job_schedule_type  \
# 0  New York, NY              via LinkedIn         Full-time
# 1  New York, NY              via LinkedIn         Full-time
# 2  New York, NY              via LinkedIn         Full-time
# 3  New York, NY  via Redstream Technology         Full-time
# 4  New York, NY          via ZipRecruiter         Full-time
#
#    job_work_from_home          search_location     job_posted_date  \
# 0               False     Texas, United States 2023-11-15 13:08:52
# 1               False  New York, United States 2023-05-08 13:08:15
# 2               False  Illinois, United States 2023-12-22 13:06:34
# 3               False  New York, United States 2023-06-25 13:00:01
# 4               False  New York, United States 2023-10-18 13:00:14
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                   True                  True  United States         NaN
# 1                  False                  True  United States         NaN
# 2                  False                 False  United States         NaN
# 3                  False                 False  United States         NaN
# 4                   True                 False  United States         NaN
#
#    salary_year_avg  salary_hour_avg  \
# 0              NaN              NaN
# 1              NaN              NaN
# 2              NaN              NaN
# 3              NaN              NaN
# 4              NaN              NaN
#
#                                       company_name  \
# 0                                            Nayya
# 1                           Career Search Partners
# 2  New York City Office of Technology & Innovation
# 3                             RedStream Technology
# 4                                        Arsenault
#
#                                           job_skills  \
# 0  ['python', 'sql', 'go', 'ruby', 'ruby', 'javas...
# 1  ['sql', 'python', 'sql server', 'excel', 'flow...
# 2  ['java', 'python', 'r', 'gcp', 'aws', 'azure',...
# 3    ['sql', 'excel', 'visio', 'powerpoint', 'word']
# 4                  ['sql', 'excel', 'microstrategy']
#
#                                      job_type_skills
# 0  {'cloud': ['aws'], 'other': ['terraform'], 'pr...
# 1  {'analyst_tools': ['excel'], 'databases': ['sq...
# 2  {'cloud': ['gcp', 'aws', 'azure'], 'libraries'...
# 3  {'analyst_tools': ['excel', 'visio', 'powerpoi...
# 4  {'analyst_tools': ['excel', 'microstrategy'], ...
